# %%
import pandas as pd

# %%
df1 = pd.read_excel('Datasets/Aracaju.xlsx')
df2 = pd.read_excel('Datasets/Fortaleza.xlsx')
df3 = pd.read_excel('Datasets/Natal.xlsx')
df4 = pd.read_excel('Datasets/Recife.xlsx')
df5 = pd.read_excel('Datasets/Salvador.xlsx')

# %%
df = pd.concat([df1,df2,df3,df4,df5])

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
df['LojaID'].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 1523     29
# 852      29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
df['LojaID'] = df['LojaID'].astype('object')

# %%
df.isna().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df['Vendas'].mean()
# Out:
# 122.61180089485438

# %%
df.sample(2)
# Out:
#        Cidade       Data  Vendas LojaID  Qtde
# 105  Salvador 2019-01-01   32.83   1037     1
# 6       Natal 2018-07-02  322.00    852     4

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita  R/V
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00  1.0
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26  6.0
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55  1.0
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07  7.0
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08  8.0

# %%
df['Receita'].max()
# Out:
# 3544.0

# %%
df.nlargest(3, 'Receita')
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  R/V
# 7   Natal 2019-03-18   886.0    853     4   3544.0  4.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0  4.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0  4.0

# %%
df.nsmallest(5,'Receita')
# Out:
#        Cidade       Data  Vendas LojaID  Qtde  Receita  R/V
# 118   Aracaju 2018-01-01    3.34   1522     1     3.34  1.0
# 65     Recife 2019-01-01    4.01    981     1     4.01  1.0
# 92      Natal 2019-01-02    4.57   1035     1     4.57  1.0
# 92   Salvador 2019-01-01    4.57   1035     1     4.57  1.0
# 95      Natal 2019-01-02    5.13   1035     1     5.13  1.0

# %%
df.groupby('Cidade')['Receita'].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
df.sample(3)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 73   Salvador 2019-01-01    8.39    1037     1
# 32    Aracaju 2018-01-01   42.97    1522     6
# 125  Salvador 2019-03-02   25.00    1037     2

# %%
df['trimestre_venda'] = df['Data'].dt.quarter

# %%
f1 = df['Ano_Venda'] == 2019
f2 = df['mes_venda'] == 3
vendas_Mar_2019 = df.loc[f1 & f2]

# %%
vendas_Mar_2019.sample(20)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Ano_Venda  mes_venda  \
# 82       Natal 2019-03-07  868.00    854     3  2604.00       2019          3
# 126     Recife 2019-03-02   41.87    980     8   334.96       2019          3
# 116   Salvador 2019-03-02   41.78   1034     3   125.34       2019          3
# 113  Fortaleza 2019-03-02   38.63    980     2    77.26       2019          3
# 111     Recife 2019-03-02    8.00    981     3    24.00       2019          3
# 132     Recife 2019-03-02   17.49    983     5    87.45       2019          3
# 127   Salvador 2019-03-02  240.61   1035     3   721.83       2019          3
# 114     Recife 2019-03-02   16.82    983     4    67.28       2019          3
# 127     Recife 2019-03-02   39.56    982     8   316.48       2019          3
# 137     Recife 2019-03-02   51.99    983     3   155.97       2019          3
# 29       Natal 2019-03-09  646.00    854     2  1292.00       2019          3
# ...

# %%
lojas = df.sample(100)

# %%
lojas.reset_index(drop=True, inplace=True)

# %%
lojas.rename(columns={'LojaID':'Loja'}, inplace=True)

# %%
lojas.to_excel('Lojas_Vendas.xlsx', index=False)
